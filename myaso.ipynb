# %%
import pandas as pd
import numpy as np
from matplotlib.pyplot import arrow

# %%
bd = pd.read_excel('data_hackathon_28062024.xlsx')

# %%
bd
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 1           7459   790055465               Нижний пруд 2023-05-06         32
# 2          10674   790055465               Нижний пруд 2023-09-09         35
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
ForCorrel = bd.select_dtypes(include='number')
ForCorrel.corr()
# Out:
#                record_id  athlete_id  n_runners  finish_time  position  \
# record_id       1.000000    0.325149  -0.031677     0.013715 -0.035832
# athlete_id      0.325149    1.000000   0.067497     0.103417  0.086893
# n_runners      -0.031677    0.067497   1.000000     0.061132  0.840256
# finish_time     0.013715    0.103417   0.061132     1.000000  0.292294
# position       -0.035832    0.086893   0.840256     0.292294  1.000000
# athlete_age     0.063348   -0.109182  -0.054475    -0.029302 -0.056170
# best_time      -0.074723    0.135129   0.091089     0.917161  0.301567
# worst_time      0.092339    0.047048   0.026789     0.869524  0.223782
# mean_time      -0.015022    0.105817   0.069621     0.951982  0.287204
# median_time    -0.026750    0.110292   0.073468     0.944545  0.289784
# times           0.368234   -0.162483  -0.087794    -0.064476 -0.109537
# num_locations   0.105364   -0.104803  -0.044005    -0.056476 -0.051990
# ...

# %%
np.percentile(bd['n_runners'], 25)
# Out:
# np.float64(26.0)

# %%
bd[bd['n_runners'] < 71][bd['n_runners'] > 26]
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 1           7459   790055465               Нижний пруд 2023-05-06         32
# 2          10674   790055465               Нижний пруд 2023-09-09         35
# 4           6755   790055533                    Бутово 2023-04-08         69
# 11          6773   790055798                      Фили 2023-04-08         41
# 12          6966   790055798                      Фили 2023-04-15         31
# ...          ...         ...                       ...        ...        ...
# 74978      13753   790163379         Коломна Парк Мира 2023-12-30         41
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
bd[bd['n_runners'] < 71]
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 1           7459   790055465               Нижний пруд 2023-05-06         32
# 2          10674   790055465               Нижний пруд 2023-09-09         35
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
import seaborn as sns

# %%
X = db[['by_one']]
X = sm.add_constant(X)
Y = db[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     25.63
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           4.27e-07
# Time:                        21:42:43   Log-Likelihood:                -35496.
# No. Observations:                5319   AIC:                         7.100e+04
# Df Residuals:                    5317   BIC:                         7.101e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1790.1258      3.746    477.874      0.000    1782.782    1797.470
# ...

# %%
sns.heatmap(ForCorrel, annot=True)

# %%
db = bd
db['CountRunners'] = db['n_runners']//5*5

# %%
db[db['n_runners'] < 71][db['n_runners'] > 26]
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 1           7459   790055465               Нижний пруд 2023-05-06         32
# 2          10674   790055465               Нижний пруд 2023-09-09         35
# 4           6755   790055533                    Бутово 2023-04-08         69
# 11          6773   790055798                      Фили 2023-04-08         41
# 12          6966   790055798                      Фили 2023-04-15         31
# ...          ...         ...                       ...        ...        ...
# 74978      13753   790163379         Коломна Парк Мира 2023-12-30         41
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
print("Hello world")

# %%
bd[bd['temp'] >= 4][bd['temp'] <= 16]
# Out:
#        record_id  athlete_id               event_name event_date  n_runners  \
# 0           6490   790055465              Нижний пруд 2023-03-25         22
# 1           7459   790055465              Нижний пруд 2023-05-06         32
# 4           6755   790055533                   Бутово 2023-04-08         69
# 7           8129   790055774  Мытищи Центральный парк 2023-06-03         21
# 8           8345   790055774  Мытищи Центральный парк 2023-06-10         21
# ...          ...         ...                      ...        ...        ...
# 74919      13858   790161180    Петровская набережная 2023-12-30         20
# 74920      13810   790161182       Волгоград панорама 2023-12-30         35
# 74922      13863   790161190                   Сириус 2023-12-30         23
# 74953      13860   790161224         Солнечный остров 2023-12-30         71
# 74981      13265   790165194         Солнечный остров 2023-12-09         35
#
# ...

# %%
db = bd
db['wind_speed'] = db['wind_speed']//1

# %%
bd['event_name'].value_counts()
# Out:
# event_name
# Затюменский                  5999
# Магнитогорск Экопарк         2818
# Солнечный остров             1539
# Пестовский                   1529
# Ростов-на-Дону               1448
#                              ...
# Петрозаводск Ямка              85
# Электросталь Авангард          35
# Котельники Кузьминский         23
# Кольчугино Городской парк      22
# Стрелка                         6
# Name: count, Length: 129, dtype: int64

# %%
db
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 1           7459   790055465               Нижний пруд 2023-05-06         32
# 2          10674   790055465               Нижний пруд 2023-09-09         35
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
db['wind_speed'].value_counts()
# Out:
# wind_speed
# 3.0     15006
# 4.0     14493
# 2.0     13281
# 1.0      9547
# 5.0      9037
# 6.0      6269
# 0.0      3099
# 7.0      2525
# 8.0      1128
# 9.0       433
# 10.0       99
# 12.0       45
# 11.0       20
# 13.0        2
# Name: count, dtype: int64

# %%
bd['wind_speed'].hist()
# Out:
# <Axes: >

# %%
bd['weather.main'].value_counts()
# Out:
# weather.main
# Clouds          38215
# Clear           21993
# Rain             7566
# Snow             4241
# Mist             1248
# Drizzle           935
# Fog               590
# Smoke             102
# Thunderstorm       65
# Haze               29
# Name: count, dtype: int64

# %%
athlet_unique = bd['athlete_id'].value_counts()
athlet_unique
# Out:
# athlete_id
# 790126905    46
# 790096365    45
# 790124229    42
# 790127953    42
# 790127217    40
#              ..
# 790161211     1
# 790161210     1
# 790161209     1
# 790161208     1
# 790109232     1
# Name: count, Length: 22563, dtype: int64

# %%
bd['дома?'] = bd['home'] == bd['event_name']

# %%
okay = pd.DataFrame({'Дома/не дома' : ['дома', 'не дома'], 'количество' : [72187, 2797], 'кол-во людей' : [22563, 1514]})

# %%
okay
# Out:
#   Дома/не дома  количество  кол-во людей
# 0         дома       72187         22563
# 1      не дома        2797          1514

# %%
bd[bd['бежит дома?'] == 1]['finish_time'].mean()
# Out:
# np.float64(1834.6197514787982)

# %%
bd[bd['бежит дома?'] == 0]['finish_time'].mean()
# Out:
# np.float64(1685.448337504469)

# %%
bd.pivot_table(index='weather.main', values='finish_time', aggfunc='mean')
# Out:
#               finish_time
# weather.main
# Clear         1817.690993
# Clouds        1827.625016
# Drizzle       2083.275936
# Fog           1872.469492
# Haze          1842.689655
# Mist          1837.997596
# Rain          1790.402194
# Smoke         1826.441176
# Snow          1905.962273
# Thunderstorm  1772.030769

# %%
bd[bd['weather.main'] == ]

# %%
bd[bd['дома?'] == 0]['athlete_id'].value_counts()
# Out:
# athlete_id
# 790126905    37
# 790131797    23
# 790128637    21
# 790096365    19
# 790129909    18
#              ..
# 790157809     1
# 790157806     1
# 790059954     1
# 790059505     1
# 790059323     1
# Name: count, Length: 1514, dtype: int64

# %%
bd['razl'] = bd['temp'] - bd['feels_like']
bd['razl'] = bd['razl']

# %%
bd
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 1           7459   790055465               Нижний пруд 2023-05-06         32
# 2          10674   790055465               Нижний пруд 2023-09-09         35
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
bd['by_one'].value_counts()
po_gradusam = pd.DataFrame({'температура: ' : ['0', '1', 'остальное'], 'количество: ' : [26458, 14592, 30959]})

# %%
po_gradusam
# Out:
#   температура:   количество:
# 0             0         26458
# 1             1         14592
# 2     остальное         30959

# %%
bd = bd.drop('norm', axis=1)

# %%
pd.concat([bd[bd['razl'] < 0], bd[bd['razl'] > 1]])['finish_time'].mean()
# температура отличапется больше чем на гредус
# среднее время прибытия
# Out:
# np.float64(1838.9110963012329)

# %%
bd[bd['razl'] >= 0][bd['razl'] <= 1]['finish_time'].mean()
# температура отличапется меньше чем на гредус
# среднее время прибытия
# Out:
# np.float64(1814.2517935199705)

# %%
bd['event_date'].value_counts()
# Out:
# event_date
# 2023-09-30    2833
# 2023-09-23    2422
# 2023-08-26    2355
# 2023-06-10    2323
# 2023-11-11    2273
# 2023-09-02    2244
# 2023-11-18    2220
# 2023-08-12    2212
# 2023-10-14    2207
# 2023-09-09    2202
# 2023-08-19    2138
# 2023-08-05    2136
# 2023-11-04    2116
# 2023-10-07    2109
# 2023-10-21    2016
# 2023-09-16    1994
# 2023-07-29    1978
# 2023-12-30    1879
# 2023-10-28    1846
# 2023-07-22    1810
# 2023-06-17    1779
# 2023-11-25    1771
# 2023-06-24    1763
# 2023-12-02    1756
# 2023-07-08    1746
# 2023-07-01    1661
# 2023-07-15    1599
# 2023-05-27    1496
# 2023-04-29    1360
# 2023-05-13    1327
# 2023-12-23    1265
# 2023-06-03    1240
# 2023-05-20    1218
# 2023-05-06    1188
# 2023-12-09    1104
# 2023-04-22    1076
# 2023-12-16    1074
# 2023-04-08    1024
# 2023-04-15     998
# 2023-04-01     840
# 2023-03-25     776
# 2023-03-18     636
# 2023-03-11     482
# 2023-03-04     384
# 2023-01-28     337
# 2023-02-25     320
# 2023-02-18     309
# ...

# %%
bd[['razl', 'finish_time']][bd['razl'] > 0].corr()
# Out:
#                  razl  finish_time
# razl         1.000000     0.031228
# finish_time  0.031228     1.000000

# %%
import scipy.stats._wilcoxon as wilcoxon
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 import scipy.stats.wilcoxon as wilcoxon
#
# ModuleNotFoundError: No module named 'scipy.stats.wilcoxon'

# %%
bd['by_two'] = round(bd['razl'], 1)

# %%
bd['event_name'].value_counts()
# Out:
# event_name
# Затюменский                  5999
# Магнитогорск Экопарк         2818
# Солнечный остров             1539
# Пестовский                   1529
# Ростов-на-Дону               1448
#                              ...
# Петрозаводск Ямка              85
# Электросталь Авангард          35
# Котельники Кузьминский         23
# Кольчугино Городской парк      22
# Стрелка                         6
# Name: count, Length: 129, dtype: int64

# %%
pivot = bd.pivot_table(index='record_id', values=['finish_time', 'by_two'], aggfunc='mean')
pivot['by_two'].value_counts()
# Out:
# by_two
#  0.0    422
#  7.0    324
#  0.3    192
#  0.2    163
#  0.5    152
#        ...
# -0.9      1
# -1.8      1
#  1.3      1
#  6.3      1
#  5.1      1
# Name: count, Length: 143, dtype: int64

# %%
pivot.pivot_table(index='by_two', values='finish_time', aggfunc='mean')
# Out:
#         finish_time
# by_two
# -5.5    1454.000000
# -5.3    2222.285714
# -3.1    1715.071429
# -2.9    1627.625000
# -1.9    1811.800000
# ...             ...
#  6.7    1779.872986
#  6.8    1849.820839
#  6.9    1865.230952
#  6.9    1671.083333
#  7.0    1833.329463
#
# [143 rows x 1 columns]

# %%
def del_out(dtf, col):
  q_low = dtf[col].quantile(0.01)
  q_hi  = dtf[col].quantile(0.99)

  return dtf[(dtf[col] < q_hi) & (dtf[col] > q_low)]

# %%
bd = del_out(bd, 'finish_time')

# %%
db = bd.pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')

# %%
db
# Out:
#            finish_time  razl
# record_id
# 4752       1693.000000  5.26
# 4753       1385.000000  0.00
# 4755       2783.000000  0.00
# 4758       1794.000000  4.72
# 4762       1835.000000  5.28
# ...                ...   ...
# 14130      1684.000000  7.00
# 14263      1648.064516  2.24
# 14274      1769.538462 -0.34
# 15198      1889.750000  4.70
# 15204      2006.349650  0.05
#
# [5319 rows x 2 columns]

# %%
pearsonr(db['finish_time'], db['razl'])
# Out:
# PearsonRResult(statistic=np.float64(0.07690431217603184), pvalue=np.float64(2.5472484508511177e-07))

# %%
from scipy.stats import spearsonr
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[121], line 1
# ----> 1 from scipy.stats import spearsonr
#
# ImportError: cannot import name 'spearsonr' from 'scipy.stats' (/Users/ssd/Documents/src/spb2024/spb2024/venv/lib/python3.9/site-packages/scipy/stats/__init__.py)

# %%
db[['razl', 'finish_time']].corr()
# Out:
#                  razl  finish_time
# razl         1.000000     0.070412
# finish_time  0.070412     1.000000

# %%
bd[['by_one', 'finish_time']].corr()
# Out:
#               by_one  finish_time
# by_one       1.00000      0.02554
# finish_time  0.02554      1.00000

# %%
db
# Out:
#            finish_time  razl
# record_id
# 4752       1693.000000  5.26
# 4753       1385.000000  0.00
# 4755       2783.000000  0.00
# 4758       1794.000000  4.72
# 4762       1835.000000  5.28
# ...                ...   ...
# 14130      1684.000000  7.00
# 14263      1648.064516  2.24
# 14274      1769.538462 -0.34
# 15198      1889.750000  4.70
# 15204      2006.349650  0.05
#
# [5319 rows x 2 columns]

# %%
db['razl'].hist()
# Out:
# <Axes: >

# %%
import statsmodels.api as sm

# %%
X = db[['razl']]
X = sm.add_constant(X)
Y = db[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     26.69
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           2.47e-07
# Time:                        21:51:20   Log-Likelihood:                -35495.
# No. Observations:                5319   AIC:                         7.099e+04
# Df Residuals:                    5317   BIC:                         7.101e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1789.7243      3.763    475.594      0.000    1782.347    1797.102
# ...

# %%
db_ust = bd[bd['times'] == 1].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.789
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):              0.181
# Time:                        22:08:38   Log-Likelihood:                -30513.
# No. Observations:                4322   AIC:                         6.103e+04
# Df Residuals:                    4320   BIC:                         6.104e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1846.9081      6.017    306.923      0.000    1835.111    1858.705
# ...

# %%
db_ust = bd[bd['times'] == 2].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.875
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):             0.0900
# Time:                        22:09:55   Log-Likelihood:                -26078.
# No. Observations:                3679   AIC:                         5.216e+04
# Df Residuals:                    3677   BIC:                         5.217e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1799.1064      6.554    274.513      0.000    1786.257    1811.956
# ...

# %%
db_ust = bd[bd['times'] == 3].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     12.54
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           0.000404
# Time:                        22:10:05   Log-Likelihood:                -22286.
# No. Observations:                3137   AIC:                         4.458e+04
# Df Residuals:                    3135   BIC:                         4.459e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1780.7459      7.138    249.489      0.000    1766.751    1794.741
# ...

# %%
db_ust = bd[bd['times'] > 3].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     41.51
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           1.30e-10
# Time:                        22:11:06   Log-Likelihood:                -30026.
# No. Observations:                4431   AIC:                         6.006e+04
# Df Residuals:                    4429   BIC:                         6.007e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1742.6839      4.416    394.609      0.000    1734.026    1751.342
# ...

# %%
db_ust = bd[bd['дома?'] == True].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     25.17
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           5.43e-07
# Time:                        22:15:01   Log-Likelihood:                -35566.
# No. Observations:                5311   AIC:                         7.114e+04
# Df Residuals:                    5309   BIC:                         7.115e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1793.7591      3.854    465.457      0.000    1786.204    1801.314
# ...

# %%
db_ust = bd[bd['дома?'] == False].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     2.970
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):             0.0850
# Time:                        22:15:13   Log-Likelihood:                -10008.
# No. Observations:                1415   AIC:                         2.002e+04
# Df Residuals:                    1413   BIC:                         2.003e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1680.7717      9.949    168.935      0.000    1661.255    1700.289
# ...

# %%
bd['weather.main'].hist()
# Out:
# <Axes: >

# %%
bd['weather.main'].value_counts()
# Out:
# weather.main
# Clouds          36624
# Clear           21188
# Rain             7305
# Snow             4071
# Mist             1215
# Drizzle           838
# Fog               574
# Smoke             101
# Thunderstorm       64
# Haze               29
# Name: count, dtype: int64

# %%
db_ust = bd[bd['weather.main'] == 'Clouds'].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.664
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):            0.00989
# Time:                        22:17:47   Log-Likelihood:                -18181.
# No. Observations:                2718   AIC:                         3.637e+04
# Df Residuals:                    2716   BIC:                         3.638e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1795.3069      5.574    322.083      0.000    1784.377    1806.237
# ...

# %%
db_ust = bd[bd['weather.main'] == 'Clear'].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.04998
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):              0.823
# Time:                        22:18:04   Log-Likelihood:                -8999.1
# No. Observations:                1364   AIC:                         1.800e+04
# Df Residuals:                    1362   BIC:                         1.801e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1792.5391      6.074    295.136      0.000    1780.624    1804.454
# ...

# %%
db_ust = bd[bd['weather.main'] != 'Clouds'][bd['weather.main'] != 'Clear'].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.020
# Method:                 Least Squares   F-statistic:                     26.56
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           2.97e-07
# Time:                        22:18:42   Log-Likelihood:                -8297.3
# No. Observations:                1237   AIC:                         1.660e+04
# Df Residuals:                    1235   BIC:                         1.661e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1776.4787      8.856    200.590      0.000    1759.104    1793.854
# ...

# %%
db_ust = bd[bd['athlete_age'] < 25].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     9.197
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):            0.00244
# Time:                        22:23:19   Log-Likelihood:                -25825.
# No. Observations:                3619   AIC:                         5.165e+04
# Df Residuals:                    3617   BIC:                         5.167e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1860.6658      6.882    270.362      0.000    1847.173    1874.159
# ...

# %%
db_ust = bd[bd['athlete_age'] >= 44][bd['athlete_age'] < 60].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     14.31
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           0.000157
# Time:                        22:25:08   Log-Likelihood:                -27943.
# No. Observations:                3960   AIC:                         5.589e+04
# Df Residuals:                    3958   BIC:                         5.590e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1787.4618      6.235    286.690      0.000    1775.238    1799.686
# ...

# %%
db_ust = bd[bd['athlete_age'] >= 75][bd['athlete_age'] < 90].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     2.136
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):              0.147
# Time:                        22:27:20   Log-Likelihood:                -779.49
# No. Observations:                 107   AIC:                             1563.
# Df Residuals:                     105   BIC:                             1568.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2494.7023     48.468     51.471      0.000    2398.599    2590.806
# ...

# %%
bd.loc[bd['event_name'].isin(['Бутово', "Пушкино Серебрянка", "Лобня Городской парк", 'Зеленоград','Долгопрудный', 'Мытищи Центральный парк','Королёв', 'Химки','Ногинск Городской парк', 'Балашиха Заречная','Электросталь Авангард','Пестовский','Люберцы Наташинский', 'Котельники Кузьминский', 'Люберцы Томилинский','Жуковский','Раменское Городской парк','Филатов Луг','Рассказовка',"Мещерский",'Павшинская Пойма Живописная набережная','Губайловский Экопарк','Митино']), "norm_city"] = "Московская область"
bd["event_name"].unique()
# Out:
# array(['Нижний пруд', 'Бутово', 'Губайловский Экопарк',
#        'Мытищи Центральный парк', 'Фили', 'ВДНХ', 'Крылатское',
#        'Коломенское', 'Сокольники', 'Сириус', 'Бабушкинский на Яузе',
#        'Кисловодский парк', 'Парк 850-летия Москвы', 'Сосновка',
#        'Йошкар-Ола Аллея Здоровья', 'Люберцы Наташинский',
#        'Мега Парк Кудрово', 'Ставрополь', 'Гатчина Приоратский',
#        'Киров Набережная Грина', 'Строгино Дорога Жизни', 'Рассказовка',
#        'Долгопрудный', 'Дружба', 'Битца', 'Вернадского', 'Парк Горького',
#        'Колпино', 'Зеленоград', 'Павшинская Пойма Живописная набережная',
#        'Челябинск', 'Митино', 'Тимирязевский', 'Набережная Реки Великой',
#        'Пестовский', 'Северное Тушино', 'Истра',
#        'Казань центральный парк', 'Александрино', 'Елагин остров',
#        'Балашиха Заречная', 'Чертаново Покровский парк', 'Мещерский',
#        'Московский парк Победы', 'Солнечный остров', 'Швейцария',
# ...

# %%
bd.loc[bd["event_name"].isin(['Бабушкинский на Яузе','Битца','Бутово','ВДНХ','Вернадского','Северное Тушино','Дружба','Зеленоград','Коломенское','Крылатское','Митино','Михалково','Парк 850-летия Москвы', 'Парк Горького','Московский парк Победы','Рассказовка','Северное Тушино','Сокольники','Строгино Дорога Жизни','Тимирязевский','Филатов Луг','Фили','Чертаново Покровский парк']), 'norm_city'] = "Москва"
bd.loc[bd["event_name"].isin(['Александрино','Елагин остров','Интернационалистов','Колпино','Московский парк Победы','Петергоф Александрийский','Пушкин','Сосновка','Гатчина Приоратский','Колпино','Мега Парк Кудрово',]), 'norm_city'] = "Питер"

# %%
bd.loc[bd["event_name"].isin(['Новосибирск набережная']), "norm_city"] = "Новосибирск"
bd.loc[bd["event_name"].isin(["Нижний пруд"]), "norm_city"] = "Калининград"

# %%
bd
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# 5          12239   790055717      Губайловский Экопарк 2023-11-04         26
# 6          12853   790055717      Губайловский Экопарк 2023-11-25         19
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
bd['norm_city'].unique()
# Out:
# array(['Калининград', 'Москва', 'Московская область', nan, 'Питер',
#        'Новосибирск'], dtype=object)

# %%
db_ust = bd[bd['norm_city'].isna()].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
X = db_ust[['razl']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     31.75
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           1.91e-08
# Time:                        22:35:33   Log-Likelihood:                -20428.
# No. Observations:                3041   AIC:                         4.086e+04
# Df Residuals:                    3039   BIC:                         4.087e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1803.7822      5.056    356.745      0.000    1793.868    1813.696
# ...

# %%
db_ust = bd.pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one', 'athlete_age', 'times', 'n_runners', 'num_locations', 'wind_speed'], aggfunc='mean')
X = db_ust[['razl', 'athlete_age', 'times', 'n_runners', 'num_locations', 'wind_speed']]
X = sm.add_constant(X)
Y = db_ust[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     13.84
# Date:                Sat, 28 Sep 2024   Prob (F-statistic):           1.13e-15
# Time:                        22:47:24   Log-Likelihood:                -35467.
# No. Observations:                5319   AIC:                         7.095e+04
# Df Residuals:                    5312   BIC:                         7.099e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1902.5519     17.115    111.164      0.000    1869.000    1936.104
# ...

# %%
bd[bd['norm_city'] == 'Москва']['finish_time'].mean()
# Out:
# np.float64(1773.384559510221)

# %%
bd[bd['norm_city'] == 'Московская область']['finish_time'].mean()
# Out:
# np.float64(1807.3337396392003)

# %%
bd[bd['norm_city'] == 'Новосибирск']['finish_time'].mean()
# Out:
# np.float64(1728.1738449490995)

# %%
bd[bd['norm_city'] == 'Калининград']['finish_time'].mean()
# Out:
# np.float64(1727.519696969697)

# %%
bd[bd['norm_city'].isna()]['finish_time'].mean()
# Out:
# np.float64(1831.5269953051643)

# %%
from scipy.stats import mannwhitneyu

# %%
df_zb = bd[bd['дома?'] == 0].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')

# %%
t00_diff = df_zb[df_zb['razl'] >= -1]
t01_diff = df_zb[df_zb['razl'] <= 1]
small_diff = pd.concat([t00_diff, t01_diff])
t0_diff = df_zb[(df_zb['razl'] < -1)]
t_diff = df_zb[df_zb['razl'] > 1]
big_diff = pd.concat([t0_diff, t_diff])

# %%
# Пример данных
group1 = small_diff['finish_time'].to_numpy()
group2 = big_diff['finish_time'].to_numpy()

# Проведение теста Манна-Уитни
statistic, p_value = mannwhitneyu(group1, group2)

# Вывод результатов
print(f'U-статистика: {statistic}')
print(f'p-значение: {p_value}')

# Интерпретация результатов
alpha = 0.05
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.")
else:
    print("Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.")

# Вычисление средних
mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)

med_group1 = np.median(group1)
med_group2 = np.median(group2)

print(f'Среднее значение группы 1: {mean_group1}')
print(f'Среднее значение группы 2: {mean_group2}')


print(f'Median группы 1: {med_group1}')
print(f'Median группы 2: {med_group2}')
# Out:
# U-статистика: 694679.5
# p-значение: 0.8229770174404762
# Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.
# Среднее значение группы 1: 1692.0732046570754
# Среднее значение группы 2: 1691.082896306092
# Median группы 1: 1665.0
# Median группы 2: 1663.0

# %%
df_zb = bd[bd['дома?'] == 0].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
t00_diff = df_zb[df_zb['razl'] >= -1]
t01_diff = df_zb[df_zb['razl'] <= 1]
small_diff = pd.concat([t00_diff, t01_diff])
t0_diff = df_zb[(df_zb['razl'] < -1)]
t_diff = df_zb[df_zb['razl'] > 1]
big_diff = pd.concat([t0_diff, t_diff])
# Пример данных
group1 = small_diff['finish_time'].to_numpy()
group2 = big_diff['finish_time'].to_numpy()

# Проведение теста Манна-Уитни
statistic, p_value = mannwhitneyu(group1, group2)

# Вывод результатов
print(f'U-статистика: {statistic}')
print(f'p-значение: {p_value}')

# Интерпретация результатов
alpha = 0.05
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.")
else:
    print("Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.")

# Вычисление средних
mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)

med_group1 = np.median(group1)
med_group2 = np.median(group2)

print(f'Среднее значение группы 1: {mean_group1}')
print(f'Среднее значение группы 2: {mean_group2}')


print(f'Median группы 1: {med_group1}')
print(f'Median группы 2: {med_group2}')
# Out:
# U-статистика: 694679.5
# p-значение: 0.8229770174404762
# Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.
# Среднее значение группы 1: 1692.0732046570754
# Среднее значение группы 2: 1691.082896306092
# Median группы 1: 1665.0
# Median группы 2: 1663.0

# %%
df_zb = bd[bd['num_locations'] > 3].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
small_diff = df_zb[df_zb['razl'] >= -1][df_zb['razl'] <= 1]
t0_diff = df_zb[(df_zb['razl'] < -1)]
t_diff = df_zb[df_zb['razl'] > 1]
big_diff = pd.concat([t0_diff, t_diff])
# Пример данных
group1 = small_diff['finish_time'].to_numpy()
group2 = big_diff['finish_time'].to_numpy()

# Проведение теста Манна-Уитни
statistic, p_value = mannwhitneyu(group1, group2)

# Вывод результатов
print(f'U-статистика: {statistic}')
print(f'p-значение: {p_value}')

# Интерпретация результатов
alpha = 0.05
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.")
else:
    print("Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.")

# Вычисление средних
mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)

med_group1 = np.median(group1)
med_group2 = np.median(group2)

print(f'Среднее значение группы 1: {mean_group1}')
print(f'Среднее значение группы 2: {mean_group2}')


print(f'Median группы 1: {med_group1}')
print(f'Median группы 2: {med_group2}')
# Out:
# U-статистика: 64846.0
# p-значение: 0.5711551166314464
# Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.
# Среднее значение группы 1: 1673.704187812188
# Среднее значение группы 2: 1693.5739783443942
# Median группы 1: 1609.6666666666667
# Median группы 2: 1640.0

# %%
df_zb = bd.pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
small_diff = df_zb[df_zb['razl'] >= -1][df_zb['razl'] <= 1]
t0_diff = df_zb[(df_zb['razl'] < -1)]
t_diff = df_zb[df_zb['razl'] > 1]
big_diff = pd.concat([t0_diff, t_diff])
# Пример данных
group1 = small_diff['finish_time'].to_numpy()
group2 = big_diff['finish_time'].to_numpy()

# Проведение теста Манна-Уитни
statistic, p_value = mannwhitneyu(group1, group2)

# Вывод результатов
print(f'U-статистика: {statistic}')
print(f'p-значение: {p_value}')

# Интерпретация результатов
alpha = 0.05
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.")
else:
    print("Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.")

# Вычисление средних
mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)

med_group1 = np.median(group1)
med_group2 = np.median(group2)

print(f'Среднее значение группы 1: {mean_group1}')
print(f'Среднее значение группы 2: {mean_group2}')


print(f'Median группы 1: {med_group1}')
print(f'Median группы 2: {med_group2}')
# Out:
# U-статистика: 3308246.0
# p-значение: 0.0034639163634297672
# Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.
# Среднее значение группы 1: 1793.0957648144527
# Среднее значение группы 2: 1811.6758322585888
# Median группы 1: 1771.6257396449705
# Median группы 2: 1790.4615384615386

# %%
t00_diff = df_zb[df_zb['razl'] >= -1]
t01_diff = df_zb[df_zb['razl'] <= 1]
small_diff = pd.concat([t00_diff, t01_diff])
t00_diff
# Out:
#            by_one  finish_time  razl
# record_id
# 4753          0.0  1385.000000  0.00
# 4755          0.0  2783.000000  0.00
# 4768          7.0  1709.000000  6.74
# 4782          5.0  1782.333333  5.42
# 4794          0.0  1912.500000  0.00
# ...           ...          ...   ...
# 14087         4.0  1883.625000  4.35
# 14130         7.0  1684.000000  7.00
# 14263         2.0  1648.064516  2.24
# 14274         0.0  1769.538462 -0.34
# 15204         0.0  2006.349650  0.05
#
# [3018 rows x 3 columns]

# %%
bd[bd['event_date'] < "2023-09-30"]
# Out:
# 0         True
# 3        False
# 4         True
# 5        False
# 6        False
#          ...
# 74979    False
# 74980    False
# 74981    False
# 74982    False
# 74983    False
# Name: event_date, Length: 72009, dtype: bool

# %%
bd['event_date']
# Out:
# 0       2023-03-25
# 3       2023-12-09
# 4       2023-04-08
# 5       2023-11-04
# 6       2023-11-25
#            ...
# 74979   2023-11-18
# 74980   2023-11-25
# 74981   2023-12-09
# 74982   2023-12-23
# 74983   2023-12-30
# Name: event_date, Length: 72009, dtype: datetime64[ns]

# %%
bd['months'] = bd.event_date.dt.month

# %%
bd['months']
# Out:
# 0         3
# 3        12
# 4         4
# 5        11
# 6        11
#          ..
# 74979    11
# 74980    11
# 74981    12
# 74982    12
# 74983    12
# Name: months, Length: 72009, dtype: int32

# %%
df_zb = bd[bd['n_runners'] >= 45].pivot_table(index='record_id', values=['finish_time', 'razl', 'by_one'], aggfunc='mean')
small_diff = df_zb[df_zb['razl'] >= -1][df_zb['razl'] <= 1]
t0_diff = df_zb[(df_zb['razl'] < -1)]
t_diff = df_zb[df_zb['razl'] > 1]
big_diff = pd.concat([t0_diff, t_diff])
# Пример данных
group1 = small_diff['finish_time'].to_numpy()
group2 = big_diff['finish_time'].to_numpy()

# Проведение теста Манна-Уитни
statistic, p_value = mannwhitneyu(group1, group2)

# Вывод результатов
print(f'U-статистика: {statistic}')
print(f'p-значение: {p_value}')

# Интерпретация результатов
alpha = 0.05
if p_value < alpha:
    print("Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.")
else:
    print("Не можем отвергнуть нулевую гипотезу: нет статистически значимых различий между группами.")

# Вычисление средних
mean_group1 = np.mean(group1)
mean_group2 = np.mean(group2)

med_group1 = np.median(group1)
med_group2 = np.median(group2)

print(f'Среднее значение группы 1: {mean_group1}')
print(f'Среднее значение группы 2: {mean_group2}')


print(f'Median группы 1: {med_group1}')
print(f'Median группы 2: {med_group2}')
# Out:
# U-статистика: 134895.0
# p-значение: 0.026112589966718384
# Отвергаем нулевую гипотезу: есть статистически значимые различия между группами.
# Среднее значение группы 1: 1786.6283985398459
# Среднее значение группы 2: 1811.866030476907
# Median группы 1: 1767.5524475524476
# Median группы 2: 1798.2241666666666

# %%
bd[bd['n_runners'] < 45]
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 5          12239   790055717      Губайловский Экопарк 2023-11-04         26
# 6          12853   790055717      Губайловский Экопарк 2023-11-25         19
# 7           8129   790055774   Мытищи Центральный парк 2023-06-03         21
# ...          ...         ...                       ...        ...        ...
# 74978      13753   790163379         Коломна Парк Мира 2023-12-30         41
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
#
# ...

# %%
db_regr = bd.pivot_table(index='record_id', values=['finish_time', 'razl', 'wind_speed', 'clouds', 'dew_point', 'humidity', 'pressure', 'athlete_age'], aggfunc='mean')
X = db_regr[['razl', 'clouds', 'wind_speed', 'humidity', 'pressure', 'athlete_age']]
X = sm.add_constant(X)
Y = db_regr[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     10.91
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           4.19e-12
# Time:                        14:19:34   Log-Likelihood:                -35476.
# No. Observations:                5319   AIC:                         7.097e+04
# Df Residuals:                    5312   BIC:                         7.101e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2487.3566    264.960      9.388      0.000    1967.927    3006.787
# ...

# %%
bd
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# 5          12239   790055717      Губайловский Экопарк 2023-11-04         26
# 6          12853   790055717      Губайловский Экопарк 2023-11-25         19
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[355], line 1
# ----> 1 from sklearn.preprocessing import OneHotEncoder
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
db_regr = df_encoded.pivot_table(index='record_id', values=['athlete_age', 'finish_time', 'razl', 'wind_speed', 'clouds', 'dew_point', 'humidity', 'pressure','athlete_gender_женский', 'athlete_gender_мужской',
       'track_description_surface_асфальт',
       'track_description_surface_асфальт и тротуарная плитка',
       'track_description_surface_асфальт, бетон',
       'track_description_surface_асфальт, грунт',
       'track_description_surface_асфальт, парковые дорожки, брусчатка',
       'track_description_surface_асфальт, плитка',
       'track_description_surface_асфальт/твердый грунт',
       'track_description_surface_беговая дорожка',
       'track_description_surface_беговая дорожка, тротуарная плитка',
       'track_description_surface_бетон',
       'track_description_surface_гранитная крошка, грунт',
       'track_description_surface_грунт',
       'track_description_surface_плитка, асфальт',
       'track_description_surface_плитка, асфальт, грунт',
       'track_description_surface_плитка, рельеф отсутствует',
       'track_description_surface_разнородное - грунт, гравий, асфальт, плитка',
       'track_description_surface_резиновая дорожка, мраморная плитка',
       'track_description_surface_смешанное',
       'track_description_surface_твердое',
       'track_description_surface_тротуарная плитка',
       'track_description_surface_тротуарная плитка, асфальт',
       'track_description_surface_частично плитка, частично мягкая беговая дорожка'], aggfunc='mean')
X = db_regr[['razl', 'clouds', 'wind_speed', 'humidity', 'pressure', 'athlete_age', 'athlete_gender_женский', 'athlete_gender_мужской',
       'track_description_surface_асфальт',
       'track_description_surface_асфальт и тротуарная плитка',
       'track_description_surface_асфальт, бетон',
       'track_description_surface_асфальт, грунт',
       'track_description_surface_асфальт, парковые дорожки, брусчатка',
       'track_description_surface_асфальт, плитка',
       'track_description_surface_асфальт/твердый грунт',
       'track_description_surface_беговая дорожка',
       'track_description_surface_беговая дорожка, тротуарная плитка',
       'track_description_surface_бетон',
       'track_description_surface_гранитная крошка, грунт',
       'track_description_surface_грунт',
       'track_description_surface_плитка, асфальт',
       'track_description_surface_плитка, асфальт, грунт',
       'track_description_surface_плитка, рельеф отсутствует',
       'track_description_surface_разнородное - грунт, гравий, асфальт, плитка',
       'track_description_surface_резиновая дорожка, мраморная плитка',
       'track_description_surface_смешанное',
       'track_description_surface_твердое',
       'track_description_surface_тротуарная плитка',
       'track_description_surface_тротуарная плитка, асфальт',
       'track_description_surface_частично плитка, частично мягкая беговая дорожка']]
X = sm.add_constant(X)
Y = db_regr[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.202
# Model:                            OLS   Adj. R-squared:                  0.198
# Method:                 Least Squares   F-statistic:                     47.87
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):          1.96e-234
# Time:                        14:58:05   Log-Likelihood:                -34908.
# No. Observations:                5319   AIC:                         6.987e+04
# Df Residuals:                    5290   BIC:                         7.006e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1752.1182    154.725     11.324      0.000    1448.794    2055.443
# ...

# %%
df_encoded = pd.get_dummies(bd, columns=['track_description_surface'])

# %%
df_encoded
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# 5          12239   790055717      Губайловский Экопарк 2023-11-04         26
# 6          12853   790055717      Губайловский Экопарк 2023-11-25         19
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
df_encoded.columns
# Out:
# Index(['record_id', 'athlete_id', 'event_name', 'event_date', 'n_runners',
#        'finish_time', 'position', 'athlete_age', 'best_time', 'worst_time',
#        'mean_time', 'median_time', 'times', 'num_locations', 'home', 'temp',
#        'feels_like', 'pressure', 'humidity', 'dew_point', 'clouds',
#        'wind_speed', 'wind_deg', 'weather.main', 'weather.description',
#        'rain.1h', 'snow.1h', 'дома?', 'razl', 'by_one', 'by_two', 'norm_city',
#        'months', 'athlete_gender_женский', 'athlete_gender_мужской',
#        'track_description_surface_асфальт',
#        'track_description_surface_асфальт и тротуарная плитка',
#        'track_description_surface_асфальт, бетон',
#        'track_description_surface_асфальт, грунт',
#        'track_description_surface_асфальт, парковые дорожки, брусчатка',
#        'track_description_surface_асфальт, плитка',
#        'track_description_surface_асфальт/твердый грунт',
#        'track_description_surface_беговая дорожка',
# ...

# %%
db_regr = df_encoded[df_encoded['athlete_gender'] == 'мужской'].pivot_table(index='record_id', values=['athlete_age', 'finish_time', 'razl', 'wind_speed', 'clouds', 'dew_point', 'humidity', 'pressure',
       'track_description_surface_асфальт',
       'track_description_surface_асфальт и тротуарная плитка',
       'track_description_surface_асфальт, бетон',
       'track_description_surface_асфальт, грунт',
       'track_description_surface_асфальт, парковые дорожки, брусчатка',
       'track_description_surface_асфальт, плитка',
       'track_description_surface_асфальт/твердый грунт',
       'track_description_surface_беговая дорожка',
       'track_description_surface_беговая дорожка, тротуарная плитка',
       'track_description_surface_бетон',
       'track_description_surface_гранитная крошка, грунт',
       'track_description_surface_грунт',
       'track_description_surface_плитка, асфальт',
       'track_description_surface_плитка, асфальт, грунт',
       'track_description_surface_плитка, рельеф отсутствует',
       'track_description_surface_разнородное - грунт, гравий, асфальт, плитка',
       'track_description_surface_резиновая дорожка, мраморная плитка',
       'track_description_surface_смешанное',
       'track_description_surface_твердое',
       'track_description_surface_тротуарная плитка',
       'track_description_surface_тротуарная плитка, асфальт',
       'track_description_surface_частично плитка, частично мягкая беговая дорожка'], aggfunc='mean')
X = db_regr[['razl', 'clouds', 'wind_speed', 'humidity', 'pressure', 'athlete_age',
       'track_description_surface_асфальт',
       'track_description_surface_асфальт и тротуарная плитка',
       'track_description_surface_асфальт, бетон',
       'track_description_surface_асфальт, грунт',
       'track_description_surface_асфальт, парковые дорожки, брусчатка',
       'track_description_surface_асфальт, плитка',
       'track_description_surface_асфальт/твердый грунт',
       'track_description_surface_беговая дорожка',
       'track_description_surface_беговая дорожка, тротуарная плитка',
       'track_description_surface_бетон',
       'track_description_surface_гранитная крошка, грунт',
       'track_description_surface_грунт',
       'track_description_surface_плитка, асфальт',
       'track_description_surface_плитка, асфальт, грунт',
       'track_description_surface_плитка, рельеф отсутствует',
       'track_description_surface_разнородное - грунт, гравий, асфальт, плитка',
       'track_description_surface_резиновая дорожка, мраморная плитка',
       'track_description_surface_смешанное',
       'track_description_surface_твердое',
       'track_description_surface_тротуарная плитка',
       'track_description_surface_тротуарная плитка, асфальт',
       'track_description_surface_частично плитка, частично мягкая беговая дорожка']]
X = sm.add_constant(X)
Y = db_regr[['finish_time']]
model = sm.OLS(np.asarray(Y), np.asarray(X))
res = model.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     13.42
# Date:                Sun, 29 Sep 2024   Prob (F-statistic):           4.59e-58
# Time:                        15:41:39   Log-Likelihood:                -34312.
# No. Observations:                5157   AIC:                         6.868e+04
# Df Residuals:                    5129   BIC:                         6.886e+04
# Df Model:                          27
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2635.4616    254.815     10.343      0.000    2135.916    3135.007
# ...

# %%
db_regr
# Out:
#            athlete_age  clouds  dew_point  finish_time  humidity  pressure  \
# record_id
# 4752         44.000000   100.0      -8.23  1693.000000      91.0    1029.0
# 4753         28.000000    75.0     -30.79  1385.000000      75.0    1028.0
# 4755         36.000000    79.0     -32.91  2783.000000      75.0    1034.0
# 4758         41.000000   100.0       0.96  1794.000000      98.0    1009.0
# 4762         34.000000   100.0       1.17  1835.000000      88.0     996.0
# ...                ...     ...        ...          ...       ...       ...
# 14130        37.600000    20.0     -18.50  1684.000000      84.0    1000.0
# 14263        31.774194     0.0      -4.98  1648.064516      74.0    1021.0
# 14274        33.923077     0.0      18.78  1769.538462      65.0    1011.0
# 15198        42.125000   100.0       0.92  1889.750000      95.0     997.0
# 15204        33.888112    50.0      14.93  2006.349650      72.0    1018.0
#
#            razl  track_description_surface_асфальт  \
# ...

# %%
df_encoded
# Out:
#        record_id  athlete_id                event_name event_date  n_runners  \
# 0           6490   790055465               Нижний пруд 2023-03-25         22
# 3          13267   790055465               Нижний пруд 2023-12-09         25
# 4           6755   790055533                    Бутово 2023-04-08         69
# 5          12239   790055717      Губайловский Экопарк 2023-11-04         26
# 6          12853   790055717      Губайловский Экопарк 2023-11-25         19
# ...          ...         ...                       ...        ...        ...
# 74979      12687   790165194  Воронеж Центральный парк 2023-11-18         35
# 74980      12934   790165194  Воронеж Центральный парк 2023-11-25         32
# 74981      13265   790165194          Солнечный остров 2023-12-09         35
# 74982      13577   790165194  Воронеж Центральный парк 2023-12-23         22
# 74983      13730   790165194  Воронеж Центральный парк 2023-12-30         48
#
# ...

# %%
bd.describe()
# Out:
#           record_id    athlete_id                     event_date  \
# count  72009.000000  7.200900e+04                          72009
# mean   10104.139649  7.901350e+08  2023-08-14 20:27:24.394450432
# min     4752.000000  7.900555e+08            2023-01-01 00:00:00
# 25%     8438.000000  7.901296e+08            2023-06-17 00:00:00
# 50%    10217.000000  7.901369e+08            2023-08-26 00:00:00
# 75%    11865.000000  7.901463e+08            2023-10-21 00:00:00
# max    15204.000000  7.901652e+08            2023-12-30 00:00:00
# std     2187.904373  1.826512e+04                            NaN
#
#           n_runners   finish_time      position   athlete_age     best_time  \
# count  72009.000000  72009.000000  72009.000000  72009.000000  72009.000000
# mean      70.172673   1812.395353     42.961449     34.892597   1723.618089
# min        1.000000   1174.000000      1.000000      4.000000    949.000000
# ...

# %%
bd['finish_time'].median()
# Out:
# np.float64(1760.0)
